# %%
print("fghj", "dfghj")

print("fghj", "dfghj", sep="---") 


## Formating

A ="Apple" 
B ="!"
print(f"I have an {A}{B}")
print("I have an {}{}".format(A,B))
print("I have an " + A+B)
print("I have an", A+B)
print("I have an", A, sep="---")


## list comprehension

Here = [1, 2, 3, 4, 5]
squared = [x**2 for x in Here]
cond = [ "Even" if x % 2 == 0 else "Odd" for x in Here]
print(f"squared = {squared}")
print(f"cond = {cond}")


list1 = ["Apple", "Banana", "Cherry"]
for i,j in enumerate(list1):
    print(i,":",j.upper(), end=" ")

lamm= list(map(lambda x: x.upper(), list1))
print(lamm)


num=[1, 2, 3, 4, 5]
a= list(map(lambda x: x**2, num))
print(a)


lam = lambda x,y : x+y
print(lam(2,4))


def square(x):
    return x**2 
print(square(5))

squared= [square(x) for x in num]
print(squared)

lamm= list(map(lambda x: x**2, num))
print(lamm)
# Out:
# fghj dfghj
# fghj---dfghj
# I have an Apple!
# I have an Apple!
# I have an Apple!
# I have an Apple!
# I have an---Apple
# squared = [1, 4, 9, 16, 25]
# cond = ['Odd', 'Even', 'Odd', 'Even', 'Odd']
# 0 : APPLE 1 : BANANA 2 : CHERRY ['APPLE', 'BANANA', 'CHERRY']
# [1, 4, 9, 16, 25]
# 6
# 25
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25]

# %% [markdown]
#  A= list(map(lambda x:x*2 , numbers))
#  B= list(map(lamda x,y:x*y , lis1,lis2))
#
#
# def square():
#     x*2
#
#  B=list(map(square,numbers))
#  C= list(filter(lamda x:x%2==0 , numbers))
#
# list comprehension
# A= [x*2 for x in lis1]
#
# import numpy as np
# a= np.array([2,3,4,5,6])
# b= np.array([4,6,2,5,6,])
# print(a*b)
#
# #o/p
# [.........]
